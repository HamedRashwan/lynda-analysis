# %%
import pandas as pd
import numpy as np

# %%
cust_df=pd.read_csv('customers.csv')
order_df=pd.read_csv('orders.csv')
prod_df=pd.read_csv('products.csv')
sale_df=pd.read_csv('sales.csv')

# %%
merge_1=pd.merge(cust_df,order_df,how='inner',on='customer_id')

# %%
merge_1
# Out:
#      customer_id      customer_name      gender  age  \
# 0              1      Leanna Busson      Female   30
# 1              1      Leanna Busson      Female   30
# 2              1      Leanna Busson      Female   30
# 3              7    Winslow Ewbanck    Bigender   76
# 4             10  Susanetta Wilshin    Bigender   70
# ..           ...                ...         ...  ...
# 995          998     Rebecka Fabler  Polygender   32
# 996          998     Rebecka Fabler  Polygender   32
# 997          998     Rebecka Fabler  Polygender   32
# 998          998     Rebecka Fabler  Polygender   32
# 999         1000   Mandel Fairbanks        Male   71
#
#                        home_address  zip_code                city  \
# 0    8606 Victoria TerraceSuite 560      5464       Johnstonhaven
# 1    8606 Victoria TerraceSuite 560      5464       Johnstonhaven
# 2    8606 Victoria TerraceSuite 560      5464       Johnstonhaven
# ...

# %%
merge_2=pd.merge(merge_1,sale_df,how='inner',on='order_id')

# %%
merge_2
# Out:
#       customer_id     customer_name  gender  age  \
# 0               1     Leanna Busson  Female   30
# 1               1     Leanna Busson  Female   30
# 2               1     Leanna Busson  Female   30
# 3               1     Leanna Busson  Female   30
# 4               1     Leanna Busson  Female   30
# ...           ...               ...     ...  ...
# 4995         1000  Mandel Fairbanks    Male   71
# 4996         1000  Mandel Fairbanks    Male   71
# 4997         1000  Mandel Fairbanks    Male   71
# 4998         1000  Mandel Fairbanks    Male   71
# 4999         1000  Mandel Fairbanks    Male   71
#
#                         home_address  zip_code                city  \
# 0     8606 Victoria TerraceSuite 560      5464       Johnstonhaven
# 1     8606 Victoria TerraceSuite 560      5464       Johnstonhaven
# 2     8606 Victoria TerraceSuite 560      5464       Johnstonhaven
# 3     8606 Victoria TerraceSuite 560      5464       Johnstonhaven
# ...

# %%
prod_df.columns=prod_df.columns.str.lower()

# %%
prod_df.columns
# Out:
# Index(['product_id', 'product_type', 'product_name', 'size', 'colour', 'price',
#        'quantity', 'description'],
#       dtype='object')

# %%
df=pd.merge(merge_2,prod_df, how='inner', on='product_id')

# %%
df
# Out:
#       customer_id         customer_name       gender  age  \
# 0               1         Leanna Busson       Female   30
# 1               1         Leanna Busson       Female   30
# 2              81         Lanny Wardale       Female   30
# 3             258         Mira Heinonen       Female   62
# 4             432         Ettie Gonnely     Bigender   34
# ...           ...                   ...          ...  ...
# 4995          971  Constance Piddington  Genderfluid   27
# 4996          980   Sharleen Langworthy      Agender   35
# 4997          986     Theodosia Postins   Polygender   38
# 4998          996        Elvira Sarfati      Agender   59
# 4999          998        Rebecka Fabler   Polygender   32
#
#                         home_address  zip_code             city  \
# 0     8606 Victoria TerraceSuite 560      5464    Johnstonhaven
# 1     8606 Victoria TerraceSuite 560      5464    Johnstonhaven
# 2        4870 Jackson SummitApt. 538      1915   Spencerborough
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     5000 non-null   int64
#  1   customer_name   5000 non-null   object
#  2   gender          5000 non-null   object
#  3   age             5000 non-null   int64
#  4   home_address    5000 non-null   object
#  5   zip_code        5000 non-null   int64
#  6   city            5000 non-null   object
#  7   state           5000 non-null   object
#  8   country         5000 non-null   object
#  9   order_id        5000 non-null   int64
#  10  payment         5000 non-null   int64
#  11  order_date      5000 non-null   object
#  12  delivery_date   5000 non-null   object
#  13  sales_id        5000 non-null   int64
#  14  product_id      5000 non-null   int64
#  15  price_per_unit  5000 non-null   int64
#  16  quantity_x      5000 non-null   int64
# ...

# %%
df.description
# Out:
# 0                 A red coloured, S sized, Chambray Shirt
# 1             A yellow coloured, L sized, Pullover Jacket
# 2             A yellow coloured, L sized, Pullover Jacket
# 3             A yellow coloured, L sized, Pullover Jacket
# 4             A yellow coloured, L sized, Pullover Jacket
#                               ...
# 4995          A violet coloured, XL sized, Leather Jacket
# 4996             A yellow coloured, XS sized, Linen Shirt
# 4997    A orange coloured, XS sized, Cargo Pants Trousers
# 4998            A yellow coloured, L sized, Puffer Jacket
# 4999                A green coloured, S sized, Polo Shirt
# Name: description, Length: 5000, dtype: object

# %%
df.describe()
# Out:
#        customer_id          age     zip_code     order_id       payment  \
# count  5000.000000  5000.000000  5000.000000  5000.000000   5000.000000
# mean    504.563000    48.760400  4912.355600   503.038200  33976.785000
# std     276.504896    17.577519  2907.367939   285.964418  14612.706539
# min       1.000000    20.000000    52.000000     1.000000  10043.000000
# 25%     276.000000    34.000000  2273.000000   258.000000  20627.000000
# 50%     509.000000    48.000000  4750.000000   504.500000  34259.000000
# 75%     733.000000    63.000000  7460.250000   749.000000  46608.000000
# max    1000.000000    80.000000  9998.000000   999.000000  59910.000000
#
#           sales_id   product_id  price_per_unit  quantity_x  total_price  \
# count  5000.000000  5000.000000     5000.000000  5000.00000  5000.000000
# mean   2499.500000   634.053200      103.501600     1.99240   206.360000
# std    1443.520003   363.255794        9.195004     0.80751    86.357457
# ...

# %%
df.isnull().sum()
# Out:
# customer_id       0
# customer_name     0
# gender            0
# age               0
# home_address      0
# zip_code          0
# city              0
# state             0
# country           0
# order_id          0
# payment           0
# order_date        0
# delivery_date     0
# sales_id          0
# product_id        0
# price_per_unit    0
# quantity_x        0
# total_price       0
# product_type      0
# product_name      0
# size              0
# colour            0
# price             0
# quantity_y        0
# description       0
# dtype: int64

# %%
df.customer_name.unique()
# Out:
# array(['Leanna Busson', 'Lanny Wardale', 'Mira Heinonen', 'Ettie Gonnely',
#        'Peri Pilsworth', 'Muire Ashtonhurst', 'Alphonse Galego',
#        'Alina Strotton', 'Melissa Partkya', 'Elizabet Pippin',
#        'Jillian Sauven', 'Elvira Sarfati', 'Hyacinth Pepper',
#        'Wadsworth Olivier', 'Ashley Gant', 'Jan Isenor', 'Wenona Stuck',
#        'Frayda Simonini', 'Miner Craddock', 'Scot Billany',
#        'Ianthe Magowan', 'Hildegarde Bamlett', 'Gayleen Brookes',
#        'Malory Emmison', 'Seana Hearons', 'Puff Newbury', 'Channa Powley',
#        'Silas Stephens', 'Reba Crauford', 'Winslow Ewbanck',
#        'Shanna Pietrzyk', 'Morgana Weymouth', 'Lisle Worthing',
#        'Crin Johnikin', 'Uriel Cottingham', 'Kakalina Ragge',
#        'Alia Rapinett', 'Ellynn Korba', 'Susanetta Wilshin',
#        'Dean McLarty', 'Lesli Pitfield', 'Anders Couvert',
#        'Lizette Lindro', 'Gallard Mangan', 'Ninnetta Lammin',
# ...

# %%
#number of customer id havenn`t loop
df.customer_id.nunique()
# Out:
# 616

# %%
df.order_id.nunique()
# Out:
# 993

# %%
df.product_id.nunique()
# Out:
# 1233

# %%
df.quantity_x.sum()
# Out:
# 9962

# %%
df.gender.value_counts()
# Out:
# gender
# Female         712
# Genderfluid    687
# Male           672
# Genderqueer    647
# Polygender     636
# Non-binary     598
# Agender        526
# Bigender       522
# Name: count, dtype: int64

# %%
df.gender.nunique()
# Out:
# 8

# %%
cust_df.gender.value_counts()
# Out:
# gender
# Male           143
# Non-binary     131
# Polygender     128
# Genderqueer    127
# Genderfluid    122
# Bigender       120
# Female         115
# Agender        114
# Name: count, dtype: int64

# %%
df.drop_duplicates().value_counts()
# Out:
# customer_id  customer_name     gender       age  home_address                    zip_code  city                state                         country    order_id  payment  order_date  delivery_date  sales_id  product_id  price_per_unit  quantity_x  total_price  product_type  product_name  size  colour  price  quantity_y  description
# 1            Leanna Busson     Female       30   8606 Victoria TerraceSuite 560  5464      Johnstonhaven       Northern Territory            Australia  455       24550    2021-4-4    2021-04-06     2245      211         106             3           318          Shirt         Chambray      S     red     105    72          A red coloured, S sized, Chambray Shirt             1
# ...

# %%
df.shape
# Out:
# (5000, 25)

# %%
df_2=df[['customer_id','gender']].drop_duplicates()
df_2.shape
# Out:
# (616, 2)

# %%
#Active User
(df_2.gender.value_counts()/df.customer_id.nunique())*100
# Out:
# gender
# Genderfluid    14.123377
# Male           13.311688
# Genderqueer    12.824675
# Polygender     12.662338
# Agender        12.337662
# Female         11.850649
# Non-binary     11.688312
# Bigender       11.201299
# Name: count, dtype: float64

# %%
df_cust_ord=df[['customer_id','order_id']].drop_duplicates().groupby('customer_id').order_id.count().reset_index().sort_values('order_id',ascending=False).reset_index()

# %%
df_3=df_cust_ord.drop('index',axis=1)

# %%
df_3.head(10
          )
# Out:
#    customer_id  order_id
# 0          571         6
# 1          348         5
# 2          566         5
# 3          664         5
# 4          282         5
# 5          711         4
# 6          206         4
# 7          107         4
# 8          549         4
# 9          620         4

# %%
max_cust_orders=list(df_3['customer_id'].head(5))

# %%
max_cust_orders
# Out:
# [571, 348, 566, 664, 282]

# %%
df_customer_order=cust_df[cust_df.customer_id.isin(max_cust_orders)]

# %%
df_customer_order
# Out:
#      customer_id    customer_name       gender  age  \
# 281          282     Wren Helgass       Female   59
# 347          348  Thorny Nornable  Genderqueer   76
# 565          566  Melissa Partkya         Male   23
# 570          571   Kristofor Roos      Agender   22
# 663          664    Dannie Fidler  Genderfluid   32
#
#                      home_address  zip_code              city  \
# 281   2634 Ward CrescentSuite 361      4527  Port Hannahburgh
# 347  4070 Nathan CircuitSuite 296      1840          Rubyfort
# 565   95 Rice Station StSuite 985      2919        O'keefeton
# 570      5567 Clarke MallApt. 756      4043        Jordanside
# 663        157 Rohan MallApt. 466      4145          East Max
#
#                             state    country
# 281  Australian Capital Territory  Australia
# 347                      Tasmania  Australia
# 565                      Tasmania  Australia
# 570  Australian Capital Territory  Australia
# 663                      Tasmania  Australia

# %%
cust_city=list(df[['customer_id','city']].drop_duplicates().city.value_counts().head(5).index)

# %%
cust_city
# Out:
# ['New Ava', 'Lake Jesse', 'East Sophia', 'Chloeville', 'Ryanberg']

# %%
#Funcation to value_counts two columns
def count_by(col1,col2,v=5):
    """
    col: id x
    col2: catigorical
    """
    return list(df[[col1,col2]].drop_duplicates()[col2].value_counts().head(v).index)

# %%
count_by('order_id','customer_id')
# Out:
# [571, 282, 566, 664, 348]

# %%
count_by('payment','customer_name')
# Out:
# ['Kristofor Roos',
#  'Wren Helgass',
#  'Melissa Partkya',
#  'Dannie Fidler',
#  'Thorny Nornable']

# %%
#Funcation to sum two columns
def sum_money(col1,col2,v=5):
    """
    col: id x
    col2: catigorical
    """
    return list(df[[col1,col2]].drop_duplicates().groupby(col1).col2)

# %%
gender_prod_count=df[['gender','product_type']].value_counts().sort_values(ascending=False).reset_index()
gender_prod_count
# Out:
#          gender product_type  count
# 0        Female       Jacket    245
# 1          Male       Jacket    239
# 2        Female     Trousers    237
# 3    Polygender     Trousers    235
# 4          Male     Trousers    230
# 5        Female        Shirt    230
# 6   Genderfluid       Jacket    230
# 7   Genderfluid        Shirt    230
# 8   Genderfluid     Trousers    227
# 9    Non-binary        Shirt    226
# 10  Genderqueer     Trousers    226
# 11  Genderqueer        Shirt    213
# 12  Genderqueer       Jacket    208
# 13         Male        Shirt    203
# 14   Polygender       Jacket    202
# 15   Polygender        Shirt    199
# 16   Non-binary     Trousers    187
# 17      Agender     Trousers    186
# 18   Non-binary       Jacket    185
# 19     Bigender       Jacket    184
# 20     Bigender        Shirt    183
# 21      Agender       Jacket    183
# 22      Agender        Shirt    157
# 23     Bigender     Trousers    155

# %%
gender_prod_count.pivot(index='gender',columns='product_type',values='count')
# Out:
# product_type  Jacket  Shirt  Trousers
# gender
# Agender          183    157       186
# Bigender         184    183       155
# Female           245    230       237
# Genderfluid      230    230       227
# Genderqueer      208    213       226
# Male             239    203       230
# Non-binary       185    226       187
# Polygender       202    199       235

# %%
list(zip(df[['order_id','product_type']].drop_duplicates().product_type.value_counts().index.to_list()\
         ,list(df[['order_id','product_type']].drop_duplicates().product_type.value_counts().values)))
# Out:
# [('Jacket', 809), ('Shirt', 805), ('Trousers', 799)]

# %%
df[['customer_id','product_id','price_per_unit']].drop_duplicates().groupby('customer_id')\
.price_per_unit.mean()
# Out:
# customer_id
# 1        96.375000
# 7       113.800000
# 10       90.000000
# 11       95.500000
# 12      103.375000
#            ...
# 994      99.714286
# 995     103.800000
# 996     103.846154
# 998     104.428571
# 1000    100.333333
# Name: price_per_unit, Length: 616, dtype: float64

# %%
df['price_per_unit'].mean()
# Out:
# 103.5016
